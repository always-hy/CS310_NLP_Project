# %% [markdown]
# ## Human Data

# %%
import pandas as pd
import numpy as np
import json
import os

# %%
news_df = pd.read_json("news.json")
webnovel_df = pd.read_json("webnovel.json")
wiki_df = pd.read_json("wiki.json")

# %%
news_df
# Out:
#                                                   input  \
# 0     打车软件补贴换花样\n本报讯记者聂根鹏报道“快的”和“滴滴”两款打车软件自本月17日宣布停止...
# 1     贵州省成功举办丹麦贵州生态环保产业恳谈会\n当前，我省正致力于推进五大新兴产业，促进经济社会...
# 2     天冷了，这些围巾系法你必须get！\n霜降过后，天气渐冷和大家分享8种漂亮围巾的围法绝对值得...
# 3     首府乳品产业借“云计算”提升竞争力\n据了解，中国乳业大数据生态公共服务平台于2015年11...
# 4     文昌小学 | “传承长征精神，动享多彩童年”秋季田径运动会隆重举行\n 10月26日上午，青...
# ...                                                 ...
# 4995           女乘客不满被查酒驾发酒疯嚷嚷扇交警耳光\n女乘客不满被查酒驾发酒疯嚷嚷扇交警耳光
# 4996  属兔的人，生在这个时辰，龙凤之命，一生多福多财\n聊不一样的风水理念，听没听过的风水知识！大...
# 4997  如何提升人人必备的核心竞争力——逻辑力？\n 点击上方“App运营之家”关注专注于移动互联网...
# 4998  深圳赴港签证一周一行 影响跨境探亲者商务人士\n据新华社电公安部出入境管理局昨日发布消息，公...
# 4999       【万门大学】德语听说7.1少女的情绪性失眠\n【万门大学】德语听说7.1少女的情绪性失眠
#
#                                                  output
# 0     补贴后，变成了以积分、抽奖等形式为主的“暗补”。一组公开的数据显示，停补后的“滴滴打车”日均...
# 1     培训、投融资等方面有着巨大的合作空间，为积极推动我省与丹麦的友好交流，促进双边经贸投资合作，...
# 2                                  环结你喜欢哪种呢？觉得不错，请点赞↓↓↓
# 3     以整合资源数据、共同打造乳业产业生态链和为政府、企业以及民众服务的高效信息化大平台。平台运作...
# ...

# %%
webnovel_df
# Out:
#                                                   input  \
# 0     给定小说简介和节选，续写小说小说简介：圣者以脊梁撑起天堂中的诸神\n王者以力量镇压地狱中的群...
# 1     我想写一本小说，给你一段正文，帮我续写正文：“要糟糕？”\n奥利弗也只能够看得到这一点点身影...
# 2     小说简介和一段话都提供给你\n后续：小说简介：魔法师的存在，是为了洞悉这个世界的真实。\n萨...
# 3     节选正文：\n光子撑起半边身子，愤怒地说：“三弟，要不今晚我们就来个全面进攻，再组织个精英小...
# 4     给你一段话：\n“可是，这怎么可能？他难道单单注视就能看出朕中毒了不成？那毒的效果你不是不知...
# ...                                                 ...
# 4995  小说简介：何为真神？神、体、力、意皆至不朽之境界，方为真神！\n秦舞阳！一路行来，经历光怪陆...
# 4996  我想写一本小说，给你一段正文，帮我续写正文：罗桀说道：“那可不一定……未必是商队。”\n郭十...
# 4997  给定节选，续写小说节选篇章：因而谁也不敢有任何掉意轻心，每个人都竖直了耳朵，生怕听漏分毫。\...
# 4998  我想写一本小说，叫做界皇\n给你一段话，帮我续写结果石锋踪迹全无。\n而这时候的石锋已经悄然...
# 4999  节选正文：\n“轰隆隆！”\n剧烈的爆炸，彻响在整片山谷，哪怕几十里外的荣耀学院成员，亦能够...
#
#                                                  output
# 0     足足有一百头之多，并且力量集中在血肉深处，真气之中，那力量爆发出来有多么的恐怖？\n嗖嗖嗖！...
# 1     尖锐的破空声音，自奥利弗的身上呼啸而过，那样恐怖的速度让奥利弗明白，不打起精神来，自己可能要...
# 2     在他灵魂深处响起：维尼，回来！\n维尼立刻放弃攻击，他连续四炮，射在相同的角度和位置上，那秩...
# 3     的长孙谨成怎么会如此的不择手段，比起叶三笑有过之而无不及，于是开口说：“三弟，现在随便你怎样...
# ...

# %%
wiki_df
# Out:
#                                                   input  \
# 0     玛丽亚·克里斯蒂娜·卡瓦列罗\n\n玛丽亚·克里斯蒂娜·卡瓦列罗（）是一位因为报道有组织犯罪...
# 1     寿同春\n\n寿同春（），原名星，字同春，号芝涯，以字行，浙江诸暨墨城坞人，清朝政治人物，监...
# 2     新克拉斯诺耶村委员会\n\n新克拉斯诺耶村委员会（）是俄罗斯联邦阿斯特拉罕州沃洛达尔斯基区所...
# 3     兰布顿县\n\n兰布顿县（）是加拿大安大略省的一个县，位于该省西南部，西北面濒临休伦湖，东北...
# 4               王冠寅\n\n王冠寅（） ，生于天津，中国男子体操运动员。强项是双杠。\n\n
# ...                                                 ...
# 4995  莫古-迪马尔塔\n\n莫古-迪马尔塔（葡萄牙语：）是葡萄牙布拉干萨区的一个堂区。总面积11....
# 4996  路易斯·德·贡戈拉·伊·阿尔戈特\n\n路易斯·德·贡戈拉·伊·阿尔戈特（Luis de G...
# 4997  恒常所得假说\n\n恒常所得假说（，缩写为 PIH），由美国经济学家米尔顿·傅利曼所发展出的...
# 4998  HD 157819\n\nHD 157819，又名CP-55 8144，SAO 244770...
# 4999      马达加斯加航空航点\n\n截至2011年1月，马达加斯加航空服务以下航点：\n\n\n\n
#
#                                                  output
# 0     韦里安纳大学获得一个通讯和新闻系学士学位，并于哈佛大学约翰·F·甘迺迪政府学院获得公共管理系...
# 1     ）林爽文起事，竹堑城失陷，程峻殉职，同春亦被贼人俘获获。贼首王作等，以刀威胁其投降。同春说了...
# 2                                             口为555人。\n
# 3     ，西面则隔圣克莱尔河与美国密芝根州圣克莱尔县对望，总面积为3002.07平方公里。据2011...
# 4
# ...
